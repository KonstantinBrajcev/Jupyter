# %% [markdown]
# Задача про МАЙОНЕЗ

# %% [markdown]
# Установка модуля УИИ

# %%
#@title Установка модуля УИИ
# !rm -rf sample_data

import seaborn as sns
import random
import os
import numpy as np
import tensorflow as tf
import gdown

# Установочные параметры
sns.set(style='darkgrid') 
seed_value = 12
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
if not os.path.exists('/content'):
  os.mkdir('/content')
os.chdir('/content')

# Загрузка модуля
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/intensivedayone.py', None, quiet=True)
import intensivedayone
demo_ai = intensivedayone.TerraIntensive()
# Out:
# "rm" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# Загружаем датасет с марками автомобилей, указав в качестве параметра метода

# %%
demo_ai.load_dataset('майонез')
# Out:
# Загрузка датасета Ok
# Инфо:
#     Вы скачали базу с изображениями брендов майонеза. База содержит 150 изображений трех категорий: «ЕЖК», «Махеев», «Ряба»

# %% [markdown]
# Выводим примеры изображений

# %%
demo_ai.samples()

# %% [markdown]
# Формируем обучающую и проверочную выборки

# %%
demo_ai.create_sets()
# Out:
# Создание наборов данных для обучения модели Ok
#
# Размер созданных выборок:
#   Обучающая выборка: (135, 96, 76, 3)
#   Метки обучающей выборки: (135,)
#   Проверочная выборка: (15, 96, 76, 3)
#   Метки проверочной выборки: (15,)
#
# Распределение по классам:

# %% [markdown]
#  Укажите слои создаваемой нейронной сети:
#
# можете попробовать взять любую модель из занятия или создать свою собственную последовательность слоев
# важно: последний слой модели должен быть Полносвязный-3

# %%
# Задание слоев нейронной сети
layers = 'Сверточный2Д-32-3\
    Выравнивающий\
        Полносвязный-32\
            Полносвязный-3'

# Создание нейронной сети
demo_ai.create_model(layers)
# Out:
# Создание модели нейронной сети Ok

# %% [markdown]
# Обучение созданной модели, используя метод demo_ai.train_model(epochs=20)

# %%
demo_ai.train_model(epochs=20)
# Out:
# Эпоха 1   Время обучения: 7.9c     Точность на обучающей выборке: 43.7%     Точность на проверочной выборке: 73.3%
# Эпоха 2   Время обучения: 6.6c     Точность на обучающей выборке: 85.9%     Точность на проверочной выборке: 66.7%
# Эпоха 3   Время обучения: 6.7c     Точность на обучающей выборке: 90.4%     Точность на проверочной выборке: 93.3%
# Эпоха 4   Время обучения: 4.6c     Точность на обучающей выборке: 96.3%     Точность на проверочной выборке: 93.3%
# Эпоха 5   Время обучения: 4.4c     Точность на обучающей выборке: 94.1%     Точность на проверочной выборке: 93.3%
# Эпоха 6   Время обучения: 4.4c     Точность на обучающей выборке: 98.5%     Точность на проверочной выборке: 100.0%
# Эпоха 7   Время обучения: 4.6c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 8   Время обучения: 5.1c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 9   Время обучения: 6.0c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 10  Время обучения: 7.5c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 93.3%
# Эпоха 11  Время обучения: 5.4c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 12  Время обучения: 5.0c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 13  Время обучения: 5.0c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 14  Время обучения: 5.2c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 15  Время обучения: 5.0c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 16  Время обучения: 4.5c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 17  Время обучения: 4.5c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 18  Время обучения: 4.6c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 19  Время обучения: 5.0c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# Эпоха 20  Время обучения: 5.6c     Точность на обучающей выборке: 100.0%    Точность на проверочной выборке: 100.0%
# При выполнении кода в текущей ячейке или предыдущей ячейке ядро аварийно завершило работу. Проверьте код в ячейках, чтобы определить возможную причину сбоя. Щелкните <a href="https://aka.ms/vscodeJupyterKernelCrash">здесь</a> для получения дополнительных сведений. Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.

# %% [markdown]
# Для демонстрации работы модели Заказчику, воспользуемся методом :

# %%
demo_ai.test_model()
# Out:
# Тестовое изображение:
# 1/1 [==============================] - 0s 183ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 0.1%
# Модель распознала класс «Mercedes» на 8.6%
# Модель распознала класс «Renault» на 91.3%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 42ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 7.3%
# Модель распознала класс «Mercedes» на 78.1%
# Модель распознала класс «Renault» на 14.7%
# ---------------------------
# Правильный ответ: Mercedes
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 39ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 12.4%
# Модель распознала класс «Mercedes» на 72.7%
# Модель распознала класс «Renault» на 14.9%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 55ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 56.7%
# Модель распознала класс «Mercedes» на 19.4%
# Модель распознала класс «Renault» на 23.9%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 33ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 2.3%
# Модель распознала класс «Mercedes» на 58.4%
# Модель распознала класс «Renault» на 39.3%
# ---------------------------
# Правильный ответ: Mercedes
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 39ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 2.7%
# Модель распознала класс «Mercedes» на 26.2%
# Модель распознала класс «Renault» на 71.1%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 34ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 2.0%
# Модель распознала класс «Mercedes» на 76.4%
# Модель распознала класс «Renault» на 21.7%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 40ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 5.2%
# Модель распознала класс «Mercedes» на 66.9%
# Модель распознала класс «Renault» на 27.8%
# ---------------------------
# Правильный ответ: Renault
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 32ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 69.7%
# Модель распознала класс «Mercedes» на 17.4%
# Модель распознала класс «Renault» на 12.9%
# ---------------------------
# Правильный ответ: Ferrari
# ---------------------------
#
#
# Тестовое изображение:
# 1/1 [==============================] - 0s 30ms/step
#
# Результат предсказания модели:
# Модель распознала класс «Ferrari» на 6.7%
# Модель распознала класс «Mercedes» на 24.5%
# Модель распознала класс «Renault» на 68.8%
# ---------------------------
# Правильный ответ: Mercedes
# ---------------------------
